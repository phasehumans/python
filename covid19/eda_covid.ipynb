# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### Data Loading

# %%
recovered_data = pd.read_csv(r'C:\Code Repo\AI Engineer\07_EDA\covid19\covid_19_recovered_v1_lyst1747728719904.csv')
recovered_data
# Out:
#             Column1             Column2     Column3     Column4  Column5  \
# 0    Province/State      Country/Region         Lat        Long  1/22/20
# 1               NaN         Afghanistan    33.93911   67.709953        0
# 2               NaN             Albania     41.1533     20.1683        0
# 3               NaN             Algeria     28.0339      1.6596        0
# 4               NaN             Andorra     42.5063      1.5218        0
# ..              ...                 ...         ...         ...      ...
# 257             NaN             Vietnam   14.058324  108.277199        0
# 258             NaN  West Bank and Gaza     31.9522     35.2332        0
# 259             NaN               Yemen   15.552727   48.516388        0
# 260             NaN              Zambia  -13.133897   27.849332        0
# 261             NaN            Zimbabwe  -19.015438   29.154857        0
#
#      Column6  Column7  Column8  Column9 Column10  ... Column489 Column490  \
# ...

# %%
deaths_data= pd.read_csv(r'C:\Code Repo\AI Engineer\07_EDA\covid19\covid_19_deaths_v1_lyst1747728711771.csv')
deaths_data
# Out:
#             Column1             Column2     Column3     Column4  Column5  \
# 0    Province/State      Country/Region         Lat        Long  1/22/20
# 1               NaN         Afghanistan    33.93911   67.709953        0
# 2               NaN             Albania     41.1533     20.1683        0
# 3               NaN             Algeria     28.0339      1.6596        0
# 4               NaN             Andorra     42.5063      1.5218        0
# ..              ...                 ...         ...         ...      ...
# 272             NaN             Vietnam   14.058324  108.277199        0
# 273             NaN  West Bank and Gaza     31.9522     35.2332        0
# 274             NaN               Yemen   15.552727   48.516388        0
# 275             NaN              Zambia  -13.133897   27.849332        0
# 276             NaN            Zimbabwe  -19.015438   29.154857        0
#
#      Column6  Column7  Column8  Column9 Column10  ... Column489 Column490  \
# ...

# %%
confirmed_data= pd.read_csv(r'C:\Code Repo\AI Engineer\07_EDA\covid19\covid_19_confirmed_v1_lyst1747728690432.csv')
confirmed_data
# Out:
#     Province/State      Country/Region        Lat        Long  1/22/20  \
# 0              NaN         Afghanistan  33.939110   67.709953        0
# 1              NaN             Albania  41.153300   20.168300        0
# 2              NaN             Algeria  28.033900    1.659600        0
# 3              NaN             Andorra  42.506300    1.521800        0
# 4              NaN              Angola -11.202700   17.873900        0
# ..             ...                 ...        ...         ...      ...
# 271            NaN             Vietnam  14.058324  108.277199        0
# 272            NaN  West Bank and Gaza  31.952200   35.233200        0
# 273            NaN               Yemen  15.552727   48.516388        0
# 274            NaN              Zambia -13.133897   27.849332        0
# 275            NaN            Zimbabwe -19.015438   29.154857        0
#
#      1/23/20  1/24/20  1/25/20  1/26/20  1/27/20  ...  5/20/21  5/21/21  \
# ...

# %% [markdown]
# ### Data Exploration

# %%
confirmed_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 276 entries, 0 to 275
# Columns: 498 entries, Province/State to 5/29/21
# dtypes: float64(2), int64(494), object(2)
# memory usage: 1.0+ MB

# %%
confirmed_data.dtypes
# Out:
# Province/State     object
# Country/Region     object
# Lat               float64
# Long              float64
# 1/22/20             int64
#                    ...
# 5/25/21             int64
# 5/26/21             int64
# 5/27/21             int64
# 5/28/21             int64
# 5/29/21             int64
# Length: 498, dtype: object

# %%
print(confirmed_data.ndim)
print(confirmed_data.size)
print(confirmed_data.shape)
# Out:
# 2
# 137448
# (276, 498)

# %%
recovered_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 262 entries, 0 to 261
# Columns: 498 entries, Column1 to Column498
# dtypes: object(498)
# memory usage: 1019.5+ KB

# %%
recovered_data.dtypes
# Out:
# Column1      object
# Column2      object
# Column3      object
# Column4      object
# Column5      object
#               ...
# Column494    object
# Column495    object
# Column496    object
# Column497    object
# Column498    object
# Length: 498, dtype: object

# %%
print(recovered_data.ndim)
print(recovered_data.size)
print(recovered_data.shape)
# Out:
# 2
# 130476
# (262, 498)

# %%
deaths_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 277 entries, 0 to 276
# Columns: 498 entries, Column1 to Column498
# dtypes: object(498)
# memory usage: 1.1+ MB

# %%
deaths_data.dtypes
# Out:
# Column1      object
# Column2      object
# Column3      object
# Column4      object
# Column5      object
#               ...
# Column494    object
# Column495    object
# Column496    object
# Column497    object
# Column498    object
# Length: 498, dtype: object

# %%
print(deaths_data.ndim)
print(deaths_data.size)
print(deaths_data.shape)
# Out:
# 2
# 137946
# (277, 498)
